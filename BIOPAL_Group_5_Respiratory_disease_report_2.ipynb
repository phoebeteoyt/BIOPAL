# %% [markdown]
# <a href="https://colab.research.google.com/github/phoebeteoyt/BIOPAL/blob/main/BIOPAL_Group_5_Respiratory_disease_report_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Title: Respiratory disease**
# **Group members:**
#
# Ciel Ong (S10269268J)
#
# Phoebe Teo (S10269171H)
#
# Gerald Seng (S10261307A)
#
# **Link to GitHub repo:**
#
# **Link to Google Colab:**
# https://colab.research.google.com/drive/1lb7_xbnSFd9fVe57CTVM-wpGBiad9dP3?authuser=2#scrollTo=RcpnV6SpznK_
#
# # **2. Declaration of contribution**
#
# We confirm that all members of the group contributed equally to the design, implementation, analysis, and writing of this research project.
#
# # **3. Summary**
#
#
# # **4. Background and rationale**
#
# ## **4.1 Health issue or knowledge gap**
#
# Chronic respiratory disease includes a range of conditions that affect multiple components of respiratory system, including the airways, parenchyma, and pulmonary vasculature. There are two types of chronic respiratory disease, communicable and noncommunicable. Communicable Chronic respiratory disease is long-term respiratory condition caused by infectious agents, while noncommunicable chronic respiratory disease are long-term respiratory conditions caused from lifestyle factors, chronic inflammation and environmental exposure. Some of the noncommunicable respiratory disease includes asthma, chronic obstructive pulmonary disease (COPD), lung cancer and others. Asthma is a major noncommunicable respiratory disease, and it has affected an estimated 262 million people in 2019, making it increasingly common these days, and it has caused 455,000 deaths according to WHO. It is also often under-diagnosed and under-treated in rural areas (with low income). To diagnose for the functioning of lungs especially when monitoring Chronic obstructive pulmonary disease, we can use spirometers to determine the ventilatory capacity of the lungs. Healthy lung size and function is dependent on four key variables, which are age, sex, height, and race, and the lung function values from the individual will be compared to normal patients with similar demographics, and if the value is below the normal range, it is considered abnormal. Some of the measurement used to interpret spirometry includes forced vital capacity (VC), forced expiratory volume in the first second (FEV 1), FEV1/FVC ratio and peak expiratory flow (PEF). In addition, elevated levels of C-reactive protein (CRP), a marker of low-grade systemic inflammation is also found associated in asthmatic individuals.
#
#
# ## **4.2 Public health and biomedical importance**
#
# This research question is important in both public health and biomedical science because it aims to understand how the different risk factors influence respiratory health and inflammation among adults with and without asthma. By identifying how factors like smoking and BMI affect the condition of the lung function in individuals with and without asthma, we can contribute to better risk stratification and promote tailored strategies to reduce the risk of chronic respiratory disease.
#
# ## **4.3 Use of NHANES and extension of existing work**
#
# This project utilizes the data from National Health and Nutrition Examination Survey (NHANES) 2007-2018 which provides us information on spirometry results, CRP levels, BMI, environmental exposure, smoking behaviour socio-economic status, gender. While previous studies have shown individual risk factors affecting lung function, this project extends existing work by analysing multiple variables simultaneously and comparing these associations between individuals with and without asthma allowing for more insights. The use of multiple biomarkers such as FEV1, FEV1/FVC ratio, peak expiratory flow and CRP levels also provides a multidimensional view of respiratory health. We hope that this analysis will clarify how lifestyle and socioeconomic affect lung function, helping to better determine better preventative actions towards respiratory diseases, particularly asthma
#
# # **5. Research question and Objectives**
#
# ## **5.1 Research question**
#
# - Using NHANES 2007-2018, among U.S. adults aged 18+, how do smoking status and BMI predict reduced FEV1/FVC ratio in individuals with and without prior asthma diagnosis?
#
# ## **5.2 Justification and novelty**
#
# Reduced lung function leading to respiratory disease can be measured by the FEV1/FVC ratio and it is influenced by various lifestyle, environmental and demographic factors. Smoking is known for being a risk factor for respiratory disease, but different smoking status (e.g. occasional smoker, regular smoker, quite smoking less than or more than 1 year ago) has different impacts on the lungs. BMI has also been associated with impaired respiratory function and systemic inflammation, which can further affect respiratory health in both non-asthmatic and asthmatic individuals. There has been research on the independent effects of smoking and BMI on lung health, but not a lot have explored how these factors jointly influence FEV1/FVC ratio in subgroups defined by asthma status.
#
# ## **5.3 Contribution to existing literature**
#
# Previous studies have shown that in non-obese individuals, BMI does not significantly affect lung function, whereas in obese individuals, BMI does affect lung function. It is also shown that non-asthmatic smokers face greater decline in FEV1 than non-asthmatic non-smokers, and asthmatic smokers face greater FEV1 decline than non-asthmatic smokers. Furthermore, it has been observed that increasing BMI is associated to lower FEV1/FVC ratios, suggesting that obesity is an independent factor that affects impairment of lung function. It however remains unclear if other risk factors such as smoking could influence this relationship, and whether asthmatics and non-asthmatics respond the same to changes in these independent factors. Through this research project, we are extending existing research by:
#
# 1.   Comparing the difference in the degree of FEV1/FVC ratio being affected by BMI and smoking in asthmatics and non-asthmatics
# 2.   Investigate the effects of Smoking, BMI and asthma status on FEV1/FVC ratio
#
# ## **5.4 SMART Objectives**
#
# 1. This study aims to investigate how smoking status and BMI predict reduced FEV1/FVC ratio in U.S. adults aged 18 and above — using measurable variables from NHANES 2007–2018 — with a feasible, time-bound analysis that addresses a relevant public health concern.
#
# 2. By analysing 12 years of NHANES data, this study will quantify how smoking and BMI contribute to impaired lung function in adults with and without asthma, providing attainable and time-bound evidence for targeted health strategies.
#
# 3. The research will use national survey data from 2007–2018 to specifically assess the predictive impact of smoking status and BMI on reduced FEV1/FVC ratio, producing relevant and measurable findings for respiratory health policy.

# %% [markdown]
# #**6. Variables and Data sources**
#
# ## **6.1 Variable Names, Codes, Units, NHANES Datasets, Descriptions, Clinical Significance**
# ### Demographic
# | Variable | NHANES Variable | Mapping / Notes |
# |----------|-----------------|-----------------|
# | Age | **RIDAGEYR** | Filter: ≥ 18 years |
# | Gender | **RIAGENDR** | 1 = Male, 2 = Female |
# | Income-to-Poverty Ratio | **INDFMPIR** | Categories: \<1, 1–2, 2–5, \>5 |
#
# ---
#
# ### Biomarker / Outcome Variables (Dependent)
# | Biomarker | NHANES Variable | Clinical Thresholds / Notes |
# |-----------|-----------------|-----------------------------|
# | C-Reactive Protein | **LBXHSCRP** | Low \< 1 mg/L, Average 1–3, High \> 3 |
# | Systolic blood pressure| Derived from **BPXSY1-4** | Normal < 120, Elevated: 120-129, High blood prssure stage 1: 130-139, High blood pressure stage 2 > 140 |
# | FEV₁/FVC Ratio | **FEV1FVC** | Abnormal \< 70 % |
#
# ---
#
# ### Body Measures
# | Body Measure | Variable | Categories |
# |--------------|----------|------------|
# | BMI | **BMXBMI** | \<18.5 = Underweight · 18.5–24.9 = Normal · 25–29.9 = Overweight · ≥30 = Obese |
#
# ---
#
# ### Health Behaviors
# | Behavior | Variable(s) | Mapping |
# |----------|-------------|---------|
# | Smoking Status | **SMQ020**, **SMQ040** | 1 = Yes, 2 = No |
# | Exercise | **PAQ605**, **PAQ620** | 1 = Yes, 2 = No |
# | Presence of Asthma | **MCQ010** | 1 = Asthma, 2 = No Asthma |
#
# ---
#
# ### Variable Types
# | Variable(s) | Type | Notes / Categories |
# |-------------|------|--------------------|
# | RIDAGEYR | Continuous | Adults ≥ 18 y |
# | RIAGENDR | Categorical | Male / Female |
# | MCQ010 | Categorical | Presence of Asthma |
# | INDFMPIR | Categorical | Socio-economic status |
# | BMXBMI | Continuous / Categorical | BMI value or category |
# | SMQ020 | Categorical | Smoking Yes/No |
# | PAQ605, PAQ620 | Categorical | Exercise Yes/No |
#
#
# ## **6.2 Total Number of Participants**
#
# | Description | Value |
# |-------------|-------|
# | Total participants included (before cleaning missing values) | **59842** |
# | Total participants included (after cleaning missing values) | **20511** |
#
# ---
#
# ## **6.3 Inclusion Criteria**
#
# | # | Criterion |
# |---|-----------|
# | 1 | Age ≥ 18 years |
# | 2 | Completed spirometry with valid **FEV1** and **FVC** data |
# | 3 | Non-missing **BMI** values |
# | 4 | Reported **smoking status** |
# | 5 | Reported **asthma diagnosis** status |
# | 6 | Valid **CRP** (C-Reactive Protein) measurement |

# %% [markdown]
# #**7. Statistical testing - Hypothesis testing**

# %% [markdown]
# ### **Importing data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Step 0: Define years and NHANES cycles
# -----------------------------
years = ["2007", "2009", "2011", "2013", "2015", "2017"]
cycles = ["E", "F", "G", "H", "I", "J"]

#Load gender, age, family income to poverty ratio data
demo_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/DEMO_{c}.xpt"
             for y, c in zip(years, cycles)]
df_demo = pd.concat([pd.read_sas(url) for url in demo_urls], ignore_index=True)

df_demo = df_demo[["SEQN", "RIAGENDR", "RIDAGEYR", "INDFMPIR"]]

#Load BMI data
bmi_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/BMX_{c}.xpt"
            for y, c in zip(years, cycles)]
df_bmi = pd.concat([pd.read_sas(url) for url in bmi_urls], ignore_index=True)

df_bmi = df_bmi[["SEQN", "BMXBMI"]]

#Load asthma status data
asthma_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/MCQ_{c}.xpt"
               for y, c in zip(years, cycles)]
df_asthma = pd.concat([pd.read_sas(url) for url in asthma_urls], ignore_index=True)

df_asthma = df_asthma[["SEQN", "MCQ010"]]  # MCQ010: "Ever told you had asthma?"

#Load Smoking status data
smq_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/SMQ_{c}.xpt"
            for y, c in zip(years, cycles)]
df_smq = pd.concat([pd.read_sas(url) for url in smq_urls], ignore_index=True)

df_smq = df_smq[["SEQN", "SMQ020", "SMQ040"]]  # Smoking status variables

# Load Spirometry (FEV1 & FVC) data
# -----------------------------
spirometry_years   = ["2007", "2009", "2011"]
spirometry_cycles  = ["E", "F", "G"]          # Only 2007–2012 have spirometry
spx_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/SPX_{c}.xpt"
            for y, c in zip(spirometry_years, spirometry_cycles)]

df_spiro = pd.concat([pd.read_sas(url) for url in spx_urls])

# keep baseline FEV1 & FVC
df_spiro = df_spiro[["SEQN", "SPXNFEV1", "SPXNFVC"]]
df_spiro = df_spiro.rename(columns={"SPXNFEV1": "FEV1", "SPXNFVC": "FVC"})

paq_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/PAQ_{c}.xpt"
            for y, c in zip(years, cycles)]
df_paq = pd.concat([pd.read_sas(url) for url in paq_urls], ignore_index=True)

df_paq = df_paq[["SEQN", "PAD660", "PAD675", "PAD680"]]

# Load CRP / hs-CRP data
import pandas as pd
import requests
import io
def crp_url_and_var(year: str, cycle_letter: str):
    if cycle_letter in {"E", "F"}:          # 2007–2010 cycles
        return (
            f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/CRP_{cycle_letter}.xpt",
            "LBXCRP",
        )
    elif cycle_letter in {"I", "J"}:        # 2015–2018 cycles
        return (
            f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/HSCRP_{cycle_letter}.xpt",
            "LBXHSCRP",
        )
    else:                                   # No CRP measured
        return None

# ------------------------------------------------------------
# Download and combine CRP / hs-CRP for all requested cycles
# ------------------------------------------------------------
crp_frames = []
for year, letter in zip(years, cycles):
    info = crp_url_and_var(year, letter)
    if info is None:
        continue                                   # skip cycles without CRP

    url, varname = info
    try:
        buffer = io.BytesIO(requests.get(url, timeout=60).content)
        tmp = pd.read_sas(buffer, format="xport")[["SEQN", varname]]
        tmp = tmp.rename(columns={varname: "LBXCRP"})
        crp_frames.append(tmp)
    except Exception:
        # silently ignore files that fail to load
        pass

# Concatenate downloaded frames; create an empty placeholder if none loaded
df_crp = (
    pd.concat(crp_frames, ignore_index=True)
    if crp_frames
    else pd.DataFrame(columns=["SEQN", "LBXCRP"])
)


#Load blood pressure data
# -----------------------------
bpx_urls = [f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/BPX_{c}.xpt"
            for y, c in zip(years, cycles)]

df_bpx = pd.concat([pd.read_sas(url) for url in bpx_urls], ignore_index=True)
df_bpx = df_bpx[["SEQN", "BPXSY1", "BPXSY2", "BPXSY3", "BPXSY4"]]

# %% [markdown]
# ### **Merging data**

# %%
# ---------------------------------------------
# Merge all NHANES tables on SEQN (left joins)
# ---------------------------------------------
df_merged = (
    df_demo
      .merge(df_bmi,    on="SEQN", how="left")
      .merge(df_asthma, on="SEQN", how="left")
      .merge(df_smq,    on="SEQN", how="left")
      .merge(df_spiro,  on="SEQN", how="left")
      .merge(df_paq,    on="SEQN", how="left")
      .merge(df_crp,    on="SEQN", how="left")
      .merge(df_bpx,    on="SEQN", how="left")
)

# Optional: derived variable
df_merged["FEV1_FVC_ratio"] = df_merged["FEV1"] / df_merged["FVC"]

# Quick check
print(df_merged.shape)
df_merged.head()
# Out:
# (59842, 19)
#       SEQN  RIAGENDR  RIDAGEYR  INDFMPIR  BMXBMI  MCQ010  SMQ020  SMQ040  \
# 0  41475.0       2.0      62.0      1.83   58.04     1.0     2.0     NaN
# 1  41476.0       2.0       6.0      5.00   15.18     2.0     NaN     NaN
# 2  41477.0       1.0      71.0      1.50   30.05     2.0     1.0     3.0
# 3  41478.0       2.0       1.0      0.66     NaN     2.0     NaN     NaN
# 4  41479.0       1.0      52.0      2.20   27.56     2.0     2.0     NaN
#
#      FEV1     FVC  PAD660  PAD675  PAD680  LBXCRP  BPXSY1  BPXSY2  BPXSY3  \
# 0  2025.0  2473.0     NaN     NaN   720.0    1.98   128.0   122.0   120.0
# 1  1551.0  1742.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN   240.0    0.07   144.0   148.0   142.0
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4  2957.0  3545.0     NaN     NaN   180.0    0.02   112.0   108.0   106.0
#
#    BPXSY4  FEV1_FVC_ratio
# 0     NaN        0.818844
# ...

# %% [markdown]
# ### **Categorizing data**

# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype

# ------------------------------------------------------------
# Helper: exercise cleaner + full categoriser
# ------------------------------------------------------------
def add_categories(df):
    out = df.copy()

    # ---------- Demographics ----------
    out["Gender"] = out["RIAGENDR"].map({1: "Male", 2: "Female"}).astype("category")
    out["AgeGroup"] = pd.cut(
        out["RIDAGEYR"],
        bins=[17, 29, 39, 49, 59, 69, 79, 89, np.inf],
        labels=["18-29", "30-39", "40-49", "50-59",
                "60-69", "70-79", "80-89", "90+"]
    ).astype("category")
    out["SES_Category"] = out["INDFMPIR"].apply(
        lambda x: "<1" if x < 1 else
                  "1–<2" if x < 2 else
                  "2–<5" if x < 5 else "≥5"
    ).astype("category")
    out["BMI_Category"] = pd.cut(
        out["BMXBMI"], [0, 18.5, 25, 30, np.inf],
        labels=["Underweight", "Normal", "Overweight", "Obese"]
    ).astype("category")

    # ---------- Smoking ----------
    def classify_smoking(row):
        if pd.isna(row["SMQ020"]):
            return np.nan
        if row["SMQ020"] == 2:
            return "Never smoked"
        if row["SMQ020"] == 1:
            if pd.isna(row["SMQ040"]):
                return np.nan
            if row["SMQ040"] == 1:
                return "Regular smoker"
            if row["SMQ040"] == 2:
                return "Occasional smoker"
            if row["SMQ040"] == 3:
                return "Reformed non-smoker"
        return np.nan
    out["Smoking"] = out.apply(classify_smoking, axis=1).astype("category")

    # ---------- Asthma ----------
    out["Asthma_Status"] = out["MCQ010"].map(
        {1: "Asthma", 2: "No Asthma"}
    ).astype("category")

    # ---------- Exercise (clean PAD* codes then classify) ----------
    # Replace NHANES skip / missing codes with NaN
    repl_long = {777: np.nan, 999: np.nan}
    repl_short = {77: np.nan, 99: np.nan}
    out["PAD660"] = out["PAD660"].replace(repl_long)
    out["PAD675"] = out["PAD675"].replace(repl_long)
    out["PAD680"] = out["PAD680"].replace(repl_short)

    def classify_activity(row):
        vig = not pd.isna(row["PAD660"]) and row["PAD660"] > 0
        mod = not pd.isna(row["PAD675"]) and row["PAD675"] > 0
        if vig and mod:
            return "Moderate & vigorous"
        elif vig:
            return "Vigorous only"
        elif mod:
            return "Moderate only"
        else:
            return "None"
    out["Exercise"] = out.apply(classify_activity, axis=1).astype("category")

    # ---------- Biomarkers ----------
    out["CRP_cat"] = pd.cut(
        out["LBXCRP"], [-np.inf, 1, 3, np.inf],
        labels=["Low risk (<1)", "Moderate risk (1-3)", "High risk (>3)"]
    ).astype("category")

    out["SBP_mean"] = out[["BPXSY1", "BPXSY2", "BPXSY3", "BPXSY4"]].mean(axis=1)
    out["SBP_cat"] = pd.cut(
        out["SBP_mean"], [0, 120, 130, 140, 180, np.inf],
        labels=["Normal (<120)", "Elevated (120-129)",
                "Stage 1 HTN", "Stage 2 HTN", "Crisis (≥180)"]
    ).astype("category")

    # ---------- Spirometry ----------
    out["FEV1_FVC_ratio"] = out["FEV1"] / out["FVC"]
    out["FEV1_FVC_ratio"] = pd.Series(
        np.where(out["FEV1_FVC_ratio"] < 0.70, "Obstructive", "Normal"),
        index=out.index
    ).astype("category")

    return out

# ------------------------------------------------------------
# Apply categorisation
# ------------------------------------------------------------
df_cat = add_categories(df_merged)

# ------------------------------------------------------------
# Print categories + counts
# ------------------------------------------------------------
cat_cols = [
    "Gender", "AgeGroup", "SES_Category", "BMI_Category",
    "Smoking", "Asthma_Status", "Exercise",
    "CRP_cat", "SBP_cat", "FEV1_FVC_ratio"
]

for col in cat_cols:
    print(f"\n===== {col} =====")
    if isinstance(df_cat[col].dtype, CategoricalDtype):
        print("Categories:", list(df_cat[col].cat.categories))
    else:
        print("Categories: (not categorical)")
    print("Counts:")
    print(df_cat[col].value_counts(dropna=False))
# Out:
# ===== Gender =====
# Categories: ['Female', 'Male']
# Counts:
# Gender
# Female    30213
# Male      29629
# Name: count, dtype: int64
#
# ===== AgeGroup =====
# Categories: ['18-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+']
# Counts:
# AgeGroup
# NaN      23262
# 18-29     7501
# 60-69     5861
# 30-39     5853
# 40-49     5745
# 50-59     5571
# 70-79     3667
# 80-89     2382
# 90+          0
# Name: count, dtype: int64
#
# ===== SES_Category =====
# Categories: ['1–<2', '2–<5', '<1', '≥5']
# Counts:
# SES_Category
# 2–<5    16918
# 1–<2    14744
# <1      14689
# ≥5      13491
# Name: count, dtype: int64
#
# ===== BMI_Category =====
# Categories: ['Underweight', 'Normal', 'Overweight', 'Obese']
# Counts:
# BMI_Category
# Normal         15583
# Obese          13882
# Overweight     12764
# Underweight    10462
# NaN             7151
# Name: count, dtype: int64
#
# ===== Smoking =====
# ...

# %% [markdown]
# ### **Missing data**

# %%
# After merging and categorizing:
df_cat = add_categories(df_merged)

# Option A: drop rows with missing values in key variables
df_clean = df_cat.dropna(subset=[
    "Gender", "AgeGroup", "SES_Category", "BMI_Category",
    "Smoking", "Asthma_Status", "FEV1_FVC_ratio", "CRP_cat", "SBP_mean"
]).reset_index(drop=True)

# Missing-data summary
df_to_check = df_clean

missing_counts = df_to_check.isna().sum()
missing_pct = (missing_counts / len(df_to_check) * 100).round(1)

missing_summary = (
    pd.concat([missing_counts, missing_pct], axis=1, keys=["n_missing", "pct_missing"])
      .sort_values("pct_missing", ascending=False)
)

print("\nMissing-data summary (sorted):")
print(missing_summary.head(20))
print("\nColumn list:")
print(df_to_check.columns.tolist())
# Out:
# Missing-data summary (sorted):
#                 n_missing  pct_missing
# BPXSY4              19425         94.7
# PAD660              15970         77.9
# PAD675              12445         60.7
# FVC                 12101         59.0
# FEV1                12101         59.0
# SMQ040              11493         56.0
# INDFMPIR             2047         10.0
# BPXSY1                821          4.0
# BPXSY3                588          2.9
# BPXSY2                518          2.5
# PAD680                 30          0.1
# RIAGENDR                0          0.0
# SEQN                    0          0.0
# SMQ020                  0          0.0
# MCQ010                  0          0.0
# RIDAGEYR                0          0.0
# BMXBMI                  0          0.0
# LBXCRP                  0          0.0
# FEV1_FVC_ratio          0          0.0
# Gender                  0          0.0
#
# Column list:
# ...

# %% [markdown]
# ### **Cleaning of data**

# %%
#Cleaned data
# 1) Basic shape
print("Rows, columns:", df_clean.shape)

# 2) Peek at the first 10 rows
from IPython.display import display
display(df_clean.head(10))

# 3) Concise column-by-column summary
df_clean.info()

# 4) Descriptive statistics for numerics
display(df_clean.describe())

# 5) Descriptive statistics for categoricals
display(df_clean.describe(include="category"))

# 6) Save so you can inspect in Excel / RStudio etc.
df_clean.to_csv("nhanes_cleaned.csv", index=False)
print("Saved to nhanes_cleaned.csv")
# Out:
# Rows, columns: (20511, 29)
#       SEQN  RIAGENDR  RIDAGEYR  INDFMPIR  BMXBMI  MCQ010  SMQ020  SMQ040  \
# 0  41475.0       2.0      62.0      1.83   58.04     1.0     2.0     NaN
# 1  41477.0       1.0      71.0      1.50   30.05     2.0     1.0     3.0
# 2  41479.0       1.0      52.0      2.20   27.56     2.0     2.0     NaN
# 3  41482.0       1.0      64.0      4.01   33.64     2.0     1.0     3.0
# 4  41483.0       1.0      66.0      1.14   44.06     2.0     2.0     NaN
# 5  41485.0       2.0      30.0      1.01   25.99     2.0     2.0     NaN
# 6  41486.0       2.0      61.0      1.75   31.21     1.0     2.0     NaN
# 7  41487.0       1.0      27.0      5.00   23.44     2.0     2.0     NaN
# 8  41489.0       2.0      40.0      2.15   36.59     2.0     2.0     NaN
# 9  41490.0       2.0      66.0      4.09   27.69     2.0     1.0     3.0
#
#      FEV1     FVC  ...  Gender  AgeGroup  SES_Category  BMI_Category  \
# ...

# %% [markdown]
# ### **Normality of FEV1/FVC ratio data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# --------------------------------------------------
# Choose the DataFrame that has FEV1 and FVC
# --------------------------------------------------
df_spiro = df_spiro.copy()              # or df_clean, df_cat …

# Compute ratio if missing
if "FEV1_FVC_ratio" not in df_spiro.columns:
    df_spiro["FEV1_FVC_ratio"] = df_spiro["FEV1"] / df_spiro["FVC"]

# Remove rows with missing or zero values
df_plot = df_spiro.dropna(subset=["FEV1", "FVC", "FEV1_FVC_ratio"])
df_plot = df_plot[df_plot["FVC"] != 0]

# --------------------------------------------------
# Histograms
# --------------------------------------------------
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
sns.histplot(df_plot["FEV1"], kde=True, color="skyblue", bins=30)
plt.title("Histogram of FEV1");  plt.xlabel("FEV1 (L)");  plt.ylabel("Frequency")

plt.subplot(1, 3, 2)
sns.histplot(df_plot["FVC"], kde=True, color="lightgreen", bins=30)
plt.title("Histogram of FVC");   plt.xlabel("FVC (L)");   plt.ylabel("Frequency")

plt.subplot(1, 3, 3)
sns.histplot(df_plot["FEV1_FVC_ratio"], kde=True, color="salmon", bins=30)
plt.title("Histogram of FEV1/FVC Ratio");  plt.xlabel("FEV1/FVC");  plt.ylabel("Frequency")

plt.tight_layout();  plt.show()

# --------------------------------------------------
# Skewness and kurtosis
# --------------------------------------------------
print("\nSkewness and Kurtosis:\n")

for col in ["FEV1", "FVC", "FEV1_FVC_ratio"]:
    clean = df_plot[col].dropna()
    print(f"{col}:  Skew = {skew(clean):.3f}   Kurtosis = {kurtosis(clean):.3f}")
# Out:
# Skewness and Kurtosis:
#
# FEV1:  Skew = 0.276   Kurtosis = -0.351
# FVC:  Skew = 0.244   Kurtosis = -0.339
# FEV1_FVC_ratio:  Skew = -0.865   Kurtosis = 2.081

# %% [markdown]
# The skewness score of FEV1/FVC ratio is between -0.5 and -1 which means that the data is moderately skewed, and the kurtosis score is more than 1 which means that the data is leptokurtic. Overall, from the scores we can see that the data is non-normally distributed. However parametric tests like ANOVA cna still be used due to the Central Limit Theorem as there is a large sample size

# %% [markdown]
# ## **FEV1/FVC ratio affected by smoking status**
# ### Using Kruskal Wallis test followed by Dunett Post-hoc test

# %%
sing Kruskal Wallis test followed by Dunett Post-hoc test

[ ]
from scipy.stats import shapiro

# Prepare FEV1/FVC as continuous ratio
df_test = df_clean.dropna(subset=["Smoking", "FEV1", "FVC"]).copy()
df_test["FEV1_FVC_cont"] = df_test["FEV1"] / df_test["FVC"]

# Shapiro–Wilk test for each smoking group
print("Shapiro–Wilk Normality Test for FEV1/FVC Ratio by Smoking Group\n")
for group in df_test["Smoking"].dropna().unique():
    values = df_test[df_test["Smoking"] == group]["FEV1_FVC_cont"]
    if len(values) > 5000:
        values = values.sample(5000, random_state=42)  # Limit for Shapiro-Wilk
    stat, p = shapiro(values)
    print(f"{group}: W = {stat:.4f}, p = {p:.4f} (n = {len(values)})")
# Out:
# Shapiro–Wilk Normality Test for FEV1/FVC Ratio by Smoking Group
#
# Never smoked: W = 0.9808, p = 0.0000 (n = 4482)
# Reformed non-smoker: W = 0.9415, p = 0.0000 (n = 1971)
# Regular smoker: W = 0.9567, p = 0.0000 (n = 1619)
# Occasional smoker: W = 0.9004, p = 0.0000 (n = 338)

# %% [markdown]
# We can see that the W values of the different smoking categories are close to 1 which means that data is close to normal distribution. However, the p values is less than 0.05, so we reject the null hypothesis, meaning that the data is significantly different from a normal distribution. Thus, we will carry out a Kruskal Wallis test

# %%
from scipy.stats import kruskal

# Group FEV1/FVC by smoking group
groups = [g["FEV1_FVC_cont"].values for name, g in df_test.groupby("Smoking")]

# Perform Kruskal–Wallis test
stat, p = kruskal(*groups)
print(f"\nKruskal–Wallis Test:\nH = {stat:.3f}, p = {p:.4f}")
# Out:
# Kruskal–Wallis Test:
# H = 508.975, p = 0.0000
# /tmp/ipython-input-20314272.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = [g["FEV1_FVC_cont"].values for name, g in df_test.groupby("Smoking")]

# %% [markdown]
# There is a statistically significant difference in the FEV1/FVC ratio among the different smoking groups.

# %%
# !pip install scikit-posthocs
import scikit_posthocs as sp

# Recalculate safely (with copy to avoid warnings)
grouped = df_clean.dropna(subset=["Smoking", "FEV1", "FVC"]).copy()
grouped["FEV1_FVC_cont"] = grouped["FEV1"] / grouped["FVC"]

# Perform Dunn's test with Bonferroni correction
posthoc = sp.posthoc_dunn(grouped, val_col="FEV1_FVC_cont", group_col="Smoking", p_adjust='bonferroni')

# Print pairwise p-values
print("Dunn's post-hoc pairwise p-values (Bonferroni-adjusted):")
print(posthoc)
# Out:
# ...
# Dunn's post-hoc pairwise p-values (Bonferroni-adjusted):
#                      Never smoked  Occasional smoker  Reformed non-smoker  \
# Never smoked         1.000000e+00       1.000000e+00         2.916957e-77
# Occasional smoker    1.000000e+00       1.000000e+00         1.141526e-12
# Reformed non-smoker  2.916957e-77       1.141526e-12         1.000000e+00
# Regular smoker       4.620752e-65       7.532921e-12         1.000000e+00
#
#                      Regular smoker
# Never smoked           4.620752e-65
# Occasional smoker      7.532921e-12
# Reformed non-smoker    1.000000e+00
# Regular smoker         1.000000e+00

# %% [markdown]
# The median FEV1/FVC ratio in Never smoked group differs significantly from Reformed non-smokers and Regular smokers, but not from Occasional smokers.
#
# The median FEV1/FVC ratio in Occasional smokers differ significantly from Reformed non-smokers and Regular smokers, but not from Never smoked.
#
# The median FEV1/FVC ratio in Reformed non-smokers and Regular smokers do not differ significantly from each other.

# %% [markdown]
# ## **Mean FEV1/FVC ratio affected by Asthma status**
# ### Using a Mann–Whitney U test

# %%
from scipy.stats import mannwhitneyu

# Prepare data (drop missing)
df_asthma_test = df_clean.dropna(subset=["Asthma_Status", "FEV1", "FVC"]).copy()
df_asthma_test["FEV1_FVC_cont"] = df_asthma_test["FEV1"] / df_asthma_test["FVC"]

# Extract groups
group_asthma = df_asthma_test[df_asthma_test["Asthma_Status"] == "Asthma"]["FEV1_FVC_cont"]
group_no_asthma = df_asthma_test[df_asthma_test["Asthma_Status"] == "No Asthma"]["FEV1_FVC_cont"]

# Perform Mann-Whitney U test
stat, p_value = mannwhitneyu(group_asthma, group_no_asthma, alternative='two-sided')

print(f"Mann-Whitney U test: statistic = {stat:.3f}, p-value = {p_value:.4f}")

# Optionally, show group means or medians
print(f"Mean FEV1/FVC ratio for Asthma: {group_asthma.mean():.3f}")
print(f"Mean FEV1/FVC ratio for No Asthma: {group_no_asthma.mean():.3f}")
# Out:
# Mann-Whitney U test: statistic = 3367736.500, p-value = 0.0000
# Mean FEV1/FVC ratio for Asthma: 0.757
# Mean FEV1/FVC ratio for No Asthma: 0.784

# %% [markdown]
# The p-value is extremely small (< 0.05), so there is a statistically significant difference in the FEV1/FVC ratio between people with asthma and those without.
#
# The mean FEV1/FVC ratio is lower in the Asthma group (0.757) compared to the No Asthma group (0.784).
#
# This suggests that people with asthma tend to have a lower FEV1/FVC ratio, which aligns with the clinical understanding that asthma can cause airway obstruction.

# %% [markdown]
# ## **Combined effect of Smoking and BMI on FEV1/FVC ratio is Asthmatics and Non-asthmatics**
# ### Using Multiple Linear Regression

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np

# Prepare your data - drop missing values in relevant columns
df_reg = df_clean.dropna(subset=["FEV1", "FVC", "Smoking", "BMXBMI", "Asthma_Status"]).copy()

# Create continuous FEV1/FVC ratio
df_reg["FEV1_FVC_cont"] = df_reg["FEV1"] / df_reg["FVC"]

# Make sure categorical variables are treated as categories
df_reg["Smoking"] = df_reg["Smoking"].astype("category")
df_reg["Asthma_Status"] = df_reg["Asthma_Status"].astype("category")
df_reg["BMI_Category"] = df_reg["BMI_Category"].astype("category")

# Formula with main effects and two-way and three-way interaction terms
formula = 'FEV1_FVC_cont ~ Smoking * BMXBMI * Asthma_Status'

# Fit the model
model = smf.ols(formula=formula, data=df_reg).fit()

# Summary of the regression
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          FEV1_FVC_cont   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     53.18
# Date:                Tue, 12 Aug 2025   Prob (F-statistic):          8.19e-153
# Time:                        17:56:29   Log-Likelihood:                 9383.4
# No. Observations:                8410   AIC:                        -1.873e+04
# Df Residuals:                    8394   BIC:                        -1.862e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                                                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Model Fit & Overall Significance:**
#
# R-squared = 0.087: About 8.7% of the variability in FEV1/FVC ratio can be explained by the variability in smoking and asthma status. The model explains a modest proportion of variability, indicating other factors likely influence FEV1/FVC ratio more
#
# F-statistic p-value ≈ 0: The overall model is statistically significant — at least one predictor (or interaction) relates to the outcome
#
# **Key findings of individual variables:**
#
# -Regular smoker (-0.0887, p=0.001): Being a regular smoker is associated with a decrease of about 0.089 in FEV1/FVC ratio compared to never smokers, statistically significant
#
# -Reformed non-smoker (-0.0599, p=0.017): Also significantly lower ratio than never smokers but smaller effect
#
# -Occasional smoker (-0.0559, p=0.187): Negative estimate but not statistically significant
#
# -Asthma_Status [No Asthma] (0.0449, p=0.003): Compared to asthmatics, non-asthmatics have on average a 0.045 higher FEV1/FVC ratio, statistically significant
#
# -BMI does not have a significant effect on FEV1/FVC ratio (p=0.072)
#
#
# **Interaction effect:**
#
# -There is no interaction effect between smoking and asthma status (p > 0.05)
#
# -There is an interaction effect between regular smoker and BMI (0.0018, p=0.036),the coeeficient indicates that among regular smokers, BMI has a small positive effect on FEV1/FVC ratio
#
# -There is no interaction effect between BMI and asthma status (p=0.136)
#
# -Smoking x BMI x Asthma_Status (three-way interaction): All p-values > 0.3, so no evidence of a three-way interaction

# %% [markdown]
# ### **Apart from the variables stated in our research question, we also want to explore how the other variables can affect FEV1/FVC ratio, and CRP level which is another biomarker of respiratory health. Furthermore, we also want to explore if the presence of asthma can lead to other health conditions:**

# %% [markdown]
# ## **FEV1/FVC ratio affected by Age and Asthma status**
# ### Using Multiple Linear Regression

# %%
import statsmodels.formula.api as smf

# Prepare dataset
df_age_test = df_clean.dropna(subset=["RIDAGEYR", "Asthma_Status", "FEV1", "FVC"]).copy()
df_age_test["FEV1_FVC_cont"] = df_age_test["FEV1"] / df_age_test["FVC"]

# Linear regression model: FEV1/FVC ~ Age + Asthma_Status + Age × Asthma_Status
model = smf.ols("FEV1_FVC_cont ~ RIDAGEYR + Asthma_Status + RIDAGEYR:Asthma_Status", data=df_age_test).fit()

# Show results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          FEV1_FVC_cont   R-squared:                       0.206
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                     725.9
# Date:                Tue, 12 Aug 2025   Prob (F-statistic):               0.00
# Time:                        17:56:29   Log-Likelihood:                 9970.4
# No. Observations:                8410   AIC:                        -1.993e+04
# Df Residuals:                    8406   BIC:                        -1.990e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Model Fit & Overall Significance:**
#
# R-squared = 0.206: About 20.6% of the variability in FEV1/FVC ratio can be explained by the variability in age and asthma status
#
# F-statistic p-value ≈ 0: The overall model is statistically significant — at least one predictor (or interaction) relates to the outcome
#
# **Key findings of individual variables:**
#
# -People without asthma have significantly higher FEV1/FVC ratio than those with asthma, by 0.026 units
#
# -For every year increase in age, FEV1/FVC ratio decreases by 0.0024
#
# -Both age and asthma status has a significant effect on FEV1/FVC ratio (p=0.000)
#
#
# **Interaction effect:**
#
# -There is no interaction effect between age and asthma status (p=0.287), age and asthma status both independently affect the FEV1/FVC ratio
#
# -Asthma impacts lung function similarly whether the person is young or old

# %% [markdown]
# ## **Association of SES with presence of Asthma**
# ### Using Chi-square test of independence

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Ensure SES_Category and Asthma_Status are clean
df_test = df_clean.dropna(subset=["SES_Category", "Asthma_Status"])

# Step 1: Create contingency table
contingency_table = pd.crosstab(df_test["SES_Category"], df_test["Asthma_Status"])

# Step 2: Run Chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Step 3: Display results
print("Chi-squared Test of Independence: SES vs. Asthma Status\n")
print("Contingency Table:\n", contingency_table)
print(f"\nChi2 Statistic = {chi2:.3f}")
print(f"Degrees of Freedom = {dof}")
print(f"p-value = {p:.4f}")

if p < 0.05:
    print("\n✅ There is a **statistically significant association** between SES and Asthma status.")
else:
    print("\n❌ There is **no significant association** between SES and Asthma status.")
# Out:
# Chi-squared Test of Independence: SES vs. Asthma Status
#
# Contingency Table:
#  Asthma_Status  Asthma  No Asthma
# SES_Category
# 1–<2              761       4342
# 2–<5              837       5518
# <1                678       3182
# ≥5                654       4539
#
# Chi2 Statistic = 54.126
# Degrees of Freedom = 3
# p-value = 0.0000
#
# ✅ There is a **statistically significant association** between SES and Asthma status.

# %% [markdown]
# ## **Effect of Gender on FEV1/FVC ratio**
# ### Using Mann-Whitney test

# %%
from scipy.stats import mannwhitneyu

# Prepare the data
df_test = df_clean.dropna(subset=["Gender", "FEV1", "FVC"]).copy()
df_test["FEV1_FVC_cont"] = df_test["FEV1"] / df_test["FVC"]

# Split by gender
male_vals = df_test[df_test["Gender"] == "Male"]["FEV1_FVC_cont"]
female_vals = df_test[df_test["Gender"] == "Female"]["FEV1_FVC_cont"]

# Mann-Whitney U Test
stat, p = mannwhitneyu(male_vals, female_vals, alternative="two-sided")

# Output results
print("Mann–Whitney U Test: FEV1/FVC Ratio by Gender\n")
print(f"Statistic = {stat:.3f}")
print(f"p-value = {p:.4f}")
print(f"Mean FEV1/FVC (Male): {male_vals.mean():.3f}")
print(f"Mean FEV1/FVC (Female): {female_vals.mean():.3f}")

# Interpretation
if p < 0.05:
    print("\n✅ There is a **statistically significant difference** in FEV1/FVC ratio between males and females.")
else:
    print("\n❌ There is **no significant difference** in FEV1/FVC ratio between males and females.")
# Out:
# Mann–Whitney U Test: FEV1/FVC Ratio by Gender
#
# Statistic = 7298325.500
# p-value = 0.0000
# Mean FEV1/FVC (Male): 0.768
# Mean FEV1/FVC (Female): 0.793
#
# ✅ There is a **statistically significant difference** in FEV1/FVC ratio between males and females.

# %% [markdown]
# ## **LogCRP affected by BMI category and Asthma Status**
# ### Using Two-way ANOVA and Tukey's HSD

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 1. Copy the cleaned data
df_anova = df_clean.copy()

# 2. Create log-transformed CRP
df_anova["log_CRP"] = np.log(df_anova["LBXCRP"].clip(lower=1e-4))

# 3. Drop missing values just in case
df_anova = df_anova.dropna(subset=["log_CRP", "BMI_Category", "Asthma_Status"])

# 4. Fit Two-way ANOVA model
model = ols("log_CRP ~ C(BMI_Category) * C(Asthma_Status)", data=df_anova).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# 5. Print the results
print("\nTwo-way ANOVA: log_CRP ~ BMI_Category * Asthma_Status")
print(anova_table)
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Tukey HSD for BMI_Category
print("\nTukey HSD: BMI_Category (all subjects, ignoring asthma)")
tukey_bmi = pairwise_tukeyhsd(
    endog=df_anova["log_CRP"],
    groups=df_anova["BMI_Category"],
    alpha=0.05
)
print(tukey_bmi)
# ✅ Interpretation for Two-way ANOVA
p_bmi      = anova_table.loc["C(BMI_Category)", "PR(>F)"]
p_asthma   = anova_table.loc["C(Asthma_Status)", "PR(>F)"]
p_interact = anova_table.loc["C(BMI_Category):C(Asthma_Status)", "PR(>F)"]

if p_bmi < 0.05:
    print("\n✅ There is a **statistically significant difference** in log(CRP) across BMI categories.")
else:
    print("\n❌ There is **no significant difference** in log(CRP) across BMI categories.")

if p_asthma < 0.05:
    print("✅ There is a **statistically significant difference** in log(CRP) between asthma and non-asthma participants.")
else:
    print("❌ There is **no significant difference** in log(CRP) between asthma and non-asthma participants.")

if p_interact < 0.05:
    print("✅ There is a **statistically significant interaction** between BMI and asthma on log(CRP).")
else:
    print("❌ There is **no significant interaction** between BMI and asthma on log(CRP).")
# Out:
# Two-way ANOVA: log_CRP ~ BMI_Category * Asthma_Status
#                                         sum_sq       df           F  \
# C(BMI_Category)                    6484.117139      3.0  829.147639
# C(Asthma_Status)                    111.736205      1.0   42.864345
# C(BMI_Category):C(Asthma_Status)     47.085064      3.0    6.020938
# Residual                          53445.991764  20503.0         NaN
#
#                                         PR(>F)
# C(BMI_Category)                   0.000000e+00
# C(Asthma_Status)                  6.005974e-11
# C(BMI_Category):C(Asthma_Status)  4.284474e-04
# Residual                                   NaN
#
# Tukey HSD: BMI_Category (all subjects, ignoring asthma)
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2   meandiff p-adj   lower   upper  reject
# -------------------------------------------------------------
#     Normal       Obese    1.348    0.0  1.2751   1.421   True
# ...

# %% [markdown]
# ## **Mean LogCRP affected by Smoking status and BMI**
# ###Using Two-way ANOVA and Tukey's HSD

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 1. Copy the cleaned dataset
df_test = df_clean.copy()

# 2. Create log-transformed CRP
df_test["log_CRP"] = np.log(df_test["LBXCRP"].clip(lower=1e-4))

# 3. Drop missing values
df_test = df_test.dropna(subset=["log_CRP", "Smoking", "BMI_Category"])

# 4. Run two-way ANOVA
model = ols("log_CRP ~ C(Smoking) * C(BMI_Category)", data=df_test).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# 5. Display results
print("\nTwo-way ANOVA: log_CRP ~ Smoking * BMI_Category")
print(anova_table)

from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Tukey HSD for Smoking
print("\nTukey HSD: Smoking")
tukey_smoking = pairwise_tukeyhsd(
    endog=df_test["log_CRP"],
    groups=df_test["Smoking"],
    alpha=0.05
)
print(tukey_smoking)

# Tukey HSD for BMI
print("\nTukey HSD: BMI_Category")
tukey_bmi = pairwise_tukeyhsd(
    endog=df_test["log_CRP"],
    groups=df_test["BMI_Category"],
    alpha=0.05
)
print(tukey_bmi)
# ✅ Interpretation for Two-way ANOVA: Smoking and BMI on log(CRP)
p_smoking   = anova_table.loc["C(Smoking)", "PR(>F)"]
p_bmi       = anova_table.loc["C(BMI_Category)", "PR(>F)"]
p_interact  = anova_table.loc["C(Smoking):C(BMI_Category)", "PR(>F)"]

if p_smoking < 0.05:
    print("\n✅ There is a **statistically significant difference** in log(CRP) between smoking groups.")
else:
    print("\n❌ There is **no significant difference** in log(CRP between smoking groups.")

if p_bmi < 0.05:
    print("✅ There is a **statistically significant difference** in log(CRP) across BMI categories.")
else:
    print("❌ There is **no significant difference** in log(CRP) across BMI categories.")

if p_interact < 0.05:
    print("✅ There is a **statistically significant interaction** between smoking and BMI on log(CRP).")
else:
    print("❌ There is **no significant interaction** between smoking and BMI on log(CRP).")
# Out:
# Two-way ANOVA: log_CRP ~ Smoking * BMI_Category
#                                   sum_sq       df           F    PR(>F)
# C(Smoking)                     36.772141      3.0    4.692198  0.002809
# C(BMI_Category)              6642.015369      3.0  847.534265  0.000000
# C(Smoking):C(BMI_Category)     29.161282      9.0    1.240346  0.264769
# Residual                    53538.879610  20495.0         NaN       NaN
#
# Tukey HSD: Smoking
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#        Never smoked   Occasional smoker   0.0635  0.745 -0.0985 0.2256  False
#        Never smoked Reformed non-smoker   0.0515 0.2913 -0.0235 0.1265  False
#        Never smoked      Regular smoker   0.0011    1.0 -0.0857  0.088  False
#   Occasional smoker Reformed non-smoker  -0.0121 0.9978 -0.1809 0.1568  False
# ...

# %% [markdown]
# ## **Mean LogCRP affected by Smoking and Asthma status**
# ###Using Two-way ANOVA and Tukey's HSD

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# 1. Copy and prep data
df_test = df_clean.copy()
df_test["log_CRP"] = np.log(df_test["LBXCRP"].clip(lower=1e-4))

# 2. Drop rows with missing smoking/asthma/CRP
df_test = df_test.dropna(subset=["log_CRP", "Smoking", "Asthma_Status"])

# 3. Run two-way ANOVA
model = ols("log_CRP ~ C(Smoking) * C(Asthma_Status)", data=df_test).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# 4. Display results
print("\nTwo-way ANOVA: log_CRP ~ Smoking * Asthma_Status")
print(anova_table)
from statsmodels.stats.multicomp import pairwise_tukeyhsd

print("\nTukey HSD for Smoking")
tukey_smoking = pairwise_tukeyhsd(
    endog=df_test["log_CRP"],
    groups=df_test["Smoking"],
    alpha=0.05
)
print(tukey_smoking)
# ✅ Interpretation for Two-way ANOVA: Smoking and Asthma_Status on log(CRP)
p_smoking   = anova_table.loc["C(Smoking)", "PR(>F)"]
p_asthma    = anova_table.loc["C(Asthma_Status)", "PR(>F)"]
p_interact  = anova_table.loc["C(Smoking):C(Asthma_Status)", "PR(>F)"]

if p_smoking < 0.05:
    print("\n✅ There is a **statistically significant difference** in log(CRP) between smoking groups.")
else:
    print("\n❌ There is **no significant difference** in log(CRP between smoking groups.")

if p_asthma < 0.05:
    print("✅ There is a **statistically significant difference** in log(CRP) between asthma and non-asthma participants.")
else:
    print("❌ There is **no significant difference** in log(CRP) between asthma and non-asthma participants.")

if p_interact < 0.05:
    print("✅ There is a **statistically significant interaction** between smoking and asthma status on log(CRP).")
else:
    print("❌ There is **no significant interaction** between smoking and asthma status on log(CRP).")
# Out:
# Two-way ANOVA: log_CRP ~ Smoking * Asthma_Status
#                                    sum_sq       df          F        PR(>F)
# C(Smoking)                      10.198322      3.0   1.162617  3.223688e-01
# C(Asthma_Status)               243.060616      1.0  83.127331  8.384738e-20
# C(Smoking):C(Asthma_Status)     17.136190      3.0   1.953540  1.186277e-01
# Residual                     59949.859455  20503.0        NaN           NaN
#
# Tukey HSD for Smoking
#              Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#        group1              group2       meandiff p-adj   lower  upper  reject
# -----------------------------------------------------------------------------
#        Never smoked   Occasional smoker   0.0635  0.745 -0.0985 0.2256  False
#        Never smoked Reformed non-smoker   0.0515 0.2913 -0.0235 0.1265  False
#        Never smoked      Regular smoker   0.0011    1.0 -0.0857  0.088  False
# ...

# %% [markdown]
# ## **Mean CRP affected by Smoking status across different age groups**
# ###Using Multiple Linear Regression

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Prepare data
df_model = df_clean.copy()
df_model["log_CRP"] = np.log(df_model["LBXCRP"].clip(lower=1e-4))

# Drop missing values
df_model = df_model.dropna(subset=["log_CRP", "Smoking", "AgeGroup"])

# Fit MLR with interaction
model = ols("log_CRP ~ C(Smoking) * C(AgeGroup)", data=df_model).fit()

# Show results
print(model.summary())
# ✅ Interpretation for MLR: Smoking × AgeGroup on log(CRP)
p_smoking   = model.pvalues.get("C(Smoking)", np.nan)  # won't exist if multiple categories
p_agegroup  = model.pvalues.get("C(AgeGroup)", np.nan)
p_interact  = model.pvalues.filter(like="C(Smoking):C(AgeGroup)").min()

# Interpret Smoking main effect (if exists)
if not np.isnan(p_smoking):
    if p_smoking < 0.05:
        print("\n✅ There is a **statistically significant main effect** of Smoking on log(CRP).")
    else:
        print("\n❌ There is **no significant main effect** of Smoking on log(CRP).")

# Interpret AgeGroup main effect
if p_agegroup < 0.05:
    print("✅ There is a **statistically significant main effect** of AgeGroup on log(CRP).")
else:
    print("❌ There is **no significant main effect** of AgeGroup on log(CRP).")

# Interpret interaction
if p_interact < 0.05:
    print("✅ There is a **statistically significant interaction** between Smoking and AgeGroup on log(CRP).")
else:
    print("❌ There is **no significant interaction** between Smoking and AgeGroup on log(CRP).")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                log_CRP   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     9.937
# Date:                Tue, 12 Aug 2025   Prob (F-statistic):           2.83e-41
# Time:                        17:56:39   Log-Likelihood:                -40016.
# No. Observations:               20511   AIC:                         8.009e+04
# Df Residuals:                   20483   BIC:                         8.031e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## **Effect of SES category on Mean LogCRP**
# ###Using One-way ANOVA

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Prepare data
df_ses = df_clean.copy()
df_ses["log_CRP"] = np.log(df_ses["LBXCRP"].clip(lower=1e-4))
df_ses = df_ses.dropna(subset=["log_CRP", "SES_Category"])

# One-way ANOVA
model = ols("log_CRP ~ C(SES_Category)", data=df_ses).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print("One-way ANOVA: log_CRP ~ SES_Category")
print(anova_table)
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(
    endog=df_ses["log_CRP"],
    groups=df_ses["SES_Category"],
    alpha=0.05
)

print(tukey)
# ✅ Interpretation for One-way ANOVA: SES_Category on log(CRP)
p_anova = anova_table.loc["C(SES_Category)", "PR(>F)"]

if p_anova < 0.05:
    print("\n✅ There is a **statistically significant difference** in log(CRP) between SES categories.")
else:
    print("\n❌ There is **no significant difference** in log(CRP) between SES categories.")
# Out:
# One-way ANOVA: log_CRP ~ SES_Category
#                        sum_sq       df         F        PR(>F)
# C(SES_Category)    142.234040      3.0  16.18298  1.672657e-10
# Residual         60079.447045  20507.0       NaN           NaN
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   1–<2   2–<5  -0.1188 0.0013 -0.2015 -0.0362   True
#   1–<2     <1   0.0317 0.8219 -0.0622  0.1255  False
#   1–<2     ≥5  -0.1802    0.0 -0.2669 -0.0935   True
#   2–<5     <1   0.1505 0.0001  0.0608  0.2402   True
#   2–<5     ≥5  -0.0613 0.2214 -0.1436  0.0209  False
#     <1     ≥5  -0.2118    0.0 -0.3053 -0.1184   True
# ----------------------------------------------------
#
# ✅ There is a **statistically significant difference** in log(CRP) between SES categories.

# %% [markdown]
# ## **LogCRP affected by Physical activity and Asthma Status**
# ###Using Multiple Linear Regression

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Step 1: Prepare data
df_reg = df_clean.copy()
df_reg["log_CRP"] = np.log(df_reg["LBXCRP"].clip(lower=1e-4))

# Step 2: Drop missing values
df_reg = df_reg.dropna(subset=["log_CRP", "Exercise", "Asthma_Status"])

# Step 3: Fit the MLR model with interaction
model = ols("log_CRP ~ C(Exercise) * C(Asthma_Status)", data=df_reg).fit()

# Step 4: Output the summary
print(model.summary())
# ✅ Interpretation for MLR: Exercise × Asthma_Status on log(CRP)
p_exercise  = model.pvalues.get("C(Exercise)", np.nan)  # may be NaN if multiple levels
p_asthma    = model.pvalues.get("C(Asthma_Status)", np.nan)
p_interact  = model.pvalues.filter(like="C(Exercise):C(Asthma_Status)").min()

# Main effect: Exercise
if not np.isnan(p_exercise):
    if p_exercise < 0.05:
        print("\n✅ There is a **statistically significant main effect** of Exercise on log(CRP).")
    else:
        print("\n❌ There is **no significant main effect** of Exercise on log(CRP).")

# Main effect: Asthma_Status
if p_asthma < 0.05:
    print("✅ There is a **statistically significant main effect** of Asthma_Status on log(CRP).")
else:
    print("❌ There is **no significant main effect** of Asthma_Status on log(CRP).")

# Interaction
if p_interact < 0.05:
    print("✅ There is a **statistically significant interaction** between Exercise and Asthma_Status on log(CRP).")
else:
    print("❌ There is **no significant interaction** between Exercise and Asthma_Status on log(CRP).")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                log_CRP   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     36.26
# Date:                Wed, 13 Aug 2025   Prob (F-statistic):           8.87e-51
# Time:                        13:49:14   Log-Likelihood:                -40024.
# No. Observations:               20511   AIC:                         8.006e+04
# Df Residuals:                   20503   BIC:                         8.013e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## **Effect of Gender on mean CRP**
# ###Using Multiple Linear Regression

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# --- Multiple Linear Regression: CRP ~ Gender + confounders ---
# Log-transform CRP to reduce skew
df_reg = df_clean.copy()
df_reg["log_CRP"] = np.log(df_reg["LBXCRP"].clip(lower=1e-4))

# Fit model (adjust for BMI, Age, Smoking, Asthma)
model = ols("log_CRP ~ C(Gender) + BMXBMI + RIDAGEYR + C(Smoking) + C(Asthma_Status)", data=df_reg).fit()

print(model.summary())

# --- Interpretation ---
p_val_gender = model.pvalues["C(Gender)[T.Male]"]

if p_val_gender < 0.05:
    print(f"\n✅ There is a **statistically significant difference** in log(CRP) between genders "
          f"(p = {p_val_gender:.4f}). Adjusting for BMI, age, smoking, and asthma, "
          f"the coefficient for male gender is {model.params['C(Gender)[T.Male]']:.4f}, "
          "meaning males tend to have lower CRP values on average compared to females "
          "(in log-scale).")
else:
    print(f"\n❌ There is **no significant difference** in log(CRP) between genders "
          f"(p = {p_val_gender:.4f}) after adjusting for BMI, age, smoking, and asthma.")
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                log_CRP   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     519.2
# Date:                Wed, 13 Aug 2025   Prob (F-statistic):               0.00
# Time:                        13:57:35   Log-Likelihood:                -38476.
# No. Observations:               20511   AIC:                         7.697e+04
# Df Residuals:                   20503   BIC:                         7.703e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## **Effect of Asthma presence on Systolic blood pressure**
# ### Using Mann-Whitney test

# %%
from scipy.stats import mannwhitneyu

# Ensure clean data
df_test = df_clean.dropna(subset=["Asthma_Status", "SBP_mean"]).copy()

# Split groups
asthma_vals = df_test[df_test["Asthma_Status"] == "Asthma"]["SBP_mean"]
no_asthma_vals = df_test[df_test["Asthma_Status"] == "No Asthma"]["SBP_mean"]

# Mann–Whitney U test
stat, p = mannwhitneyu(asthma_vals, no_asthma_vals, alternative="two-sided")

# Print results
print("Mann–Whitney U Test: SBP by Asthma Status\n")
print(f"Statistic = {stat:.3f}")
print(f"p-value = {p:.4f}")
print(f"Mean SBP (Asthma): {asthma_vals.mean():.2f}")
print(f"Mean SBP (No Asthma): {no_asthma_vals.mean():.2f}")

# Interpretation
if p < 0.05:
    print("\n✅ There is a **significant difference** in systolic blood pressure between individuals with and without asthma.")
else:
    print("\n❌ There is **no significant difference** in systolic blood pressure between individuals with and without asthma.")
# Out:
# Mann–Whitney U Test: SBP by Asthma Status
#
# Statistic = 24924395.000
# p-value = 0.0051
# Mean SBP (Asthma): 123.33
# Mean SBP (No Asthma): 124.63
#
# ✅ There is a **significant difference** in systolic blood pressure between individuals with and without asthma.

# %% [markdown]
# # **8. Conclusions and future work**

# %% [markdown]
# ## **8.1 Outcomes**
#
# **Interpretation:**
#
# From our analysis, FEV1/FVC ratio was significantly different across different smoking status, and smoking status was a strong predictor with individuals who never smoked and occassional smokers having higher FEV1/FVC ratio while there was not much difference between reformed and regular smoker. When investigating the combined effects of smoking and BMI on FEV1/FVC ratio, smoking remains a significant factor while BMI does not have much of a significant effect on FEV1/FVC ratio, indicating that BMI is a poor indicator of our lung health. Asthma presence and increasing age was also associated with lower FEV1/FVC ratio. Overall, the different risk factors did not show any interaction effect, suggesting that they affect our lung health independently.
#
# For the risk factors affecting CRP levels, BMI appears to be the strongest predictor of CRP levels, and its interaction with asthma also affects the CRP levels. Smoking has a smaller effect on CRP levels as compared to BMI as there were cases where smoking has no significant effect on CRP levels. Furthermore, SES and gender also contribute to differences in CRP levels.
#
# Lastly, we also observed that our lung health can also lead to other problems, such as affecting our systolic blood pressure
#
# **Public health implications:**
#
# These findings highlight the importance of quiting smoking as shown by how it greatly affects our lung function as seen from the FEV1/FVC ratio and CRP levels. BMI displaying a storng significant effect on CRP levels also shows the need for preventing obesity through diet or lifestyle changes. Furthermore, higher SES was also shown to be associated with better lung health, suggesting that improving social conditions and healthcare assess for those of lower income groups can reduce health implications.
#
# **Limitations**
#
# This analysis is based on NHANES data which is cross sectional, and thus cannot establish casuality. There are also multiple variables used in this analysis, such as  smoking status, asthma status, which relies on self reporting and not verified through medical records which may introduce recall or reporting bias, hence affecting the reliablity of the data.

# %% [markdown]
# | **Factor** | **CRP (Inflammation)** | **FEV1/FVC (Lung Function)** | **Notes** |
# |------------|------------------------|------------------------------|-----------|
# | **BMI** | ✅ Significant — higher BMI increases CRP | ✅ Significant — higher BMI lowers ratio | Strong predictor in both outcomes |
# | **Asthma** | ✅ Significant — effect varies by BMI (interaction) | ✅ Significant — reduces ratio, but smaller effect than smoking/BMI | Stronger role in inflammation than lung function |
# | **Smoking** | ✅ Significant — independent effect | ✅ Significant — largest drop in ratio; effect amplified with high BMI | Stronger effect on lung function than inflammation |
# | **Smoking × BMI** | ❌ No significant interaction | ✅ Significant — largest lung function drop | Key combined risk for lung function |
# | **Smoking × Asthma** | ✅ Significant — asthma-driven effect | ❌ Not significant | Relevant only for inflammation |
# | **Age** | ❌ Not significant | ✅ Significant — reduces ratio (smaller effect than smoking/BMI) | Minor overall influence |
# | **SES** | ✅ Significant — linked to CRP category | - | Social disparities in inflammation  |
# | **Physical Activity** | ❌ Not significant | ❌ Not significant | No effect detected |
# | **Gender** | ✅ Significant — differences in CRP levels | ✅ Significant — differences in lung function | Consistent across outcomes |

# %% [markdown]
# ## **8.2 Future Work**
# ### **Tests for further analysis:**
# **1. Survey-weighted logistic regression**
#
# This method would translate our continuous measures of lung function (FEV1/FVC) and inflammation (CRP) into clinically relevant categories such as “low lung function” or “high inflammation.” It would allow us to estimate the odds of being in these high-risk groups based on smoking, BMI, and asthma status, making our results more applicable for risk prediction and screening purposes.
#
#
# **2. Adjusted interaction analysis**
#
# Further testing could confirm whether the smoking–BMI effect on lung function and the BMI–asthma effect on inflammation remain significant after adjusting for other covariates such as age and gender. This would help clarify whether the observed interactions are independent or influenced by other factors.
#
# **3. Mediation analysis**
#
# This would explore whether inflammation (CRP) acts as a mediator in the relationship between BMI and systolic blood pressure, helping to explain the biological pathway that links weight to cardiovascular strain.
#
# **4. Multiple regression**
#
# By including CRP, lung function, BMI, smoking, and asthma together in a single model for systolic blood pressure, we could determine which factors have the strongest overall effect when controlling for the others.
#
# **5. Temporal trend analysis**
#
# This would examine whether the strength or direction of the associations between key risk factors and our three indicators (FEV1/FVC, CRP, SBP) has changed across different NHANES survey cycles, helping identify evolving public health patterns.
#
#
# | Test | Indicator | Factors to Study | Reason |
# |---|---|---|---|
# | Survey-weighted logistic regression | FEV1/FVC (low lung function), CRP (high inflammation) | Smoking, BMI, Asthma | To find out the chance of being “high risk” instead of just average differences |
# | Adjusted interaction analysis | FEV1/FVC | Regular smoker × BMI | To check if the smoker–BMI link we found still holds after considering other factors |
# | Adjusted interaction analysis | CRP | BMI × Asthma | To measure how much asthma changes the BMI–CRP link after adjusting for other factors |
# | Mediation analysis | SBP | BMI → CRP → SBP | To see if inflammation explains why BMI is linked to higher blood pressure |
# | Multiple regression | SBP | CRP, FEV1/FVC, BMI, Smoking, Asthma | To find which factor matters most for blood pressure when all are tested together |
# | Temporal trends | FEV1/FVC, CRP | Smoking, BMI, Asthma | To check if these health links have changed over the years |

# %% [markdown]
# ### **Additional Predictors that have not been included:**
#
# | Predictor (NHANES)   | Reason for Inclusion |
# |----------------------|----------------------|
# | Race/Ethnicity       | May influence lung health, inflammation, and blood pressure due to genetic and social factors. |
# | Diet                 | Nutrient intake affects weight, inflammation, and overall cardiovascular health. |
# | Alcohol Consumption  | Can impact blood pressure, inflammation, and respiratory health. |
# | Blood Lipid Levels   | Indicators of cardiovascular risk, possibly linked to inflammation and blood pressure. |
# | Sleep Patterns       | Poor sleep can affect immune function, inflammation, and cardiovascular health. |

# %% [markdown]
# # **9. Use of AI**

# %% [markdown]
# ## **9.1 Problem**
# As stated before, our research question is "Using NHANES 2007-2018, among U.S. adults aged 18+, how do smoking status and BMI predict reduced FEV1/FVC ratio in individuals with and without prior asthma diagnosis?"
#
# Regarding these factors and biomarkers, existing studies often focus on one outcome or one risk factor at a time, making it harder for us to understand their combined or interactive effects. This gap makes it challenging for people to design effective public health strategies that address multiple health risks together.
#
# Therefore, our project aimed to conduct integrated analysis to investigate how key risk factors—such as smoking status, BMI, asthma status, and other demographic or lifestyle variables affect lung function (FEV1/FVC ratio), systemic inflammation (CRP levels), and systolic blood pressure in the U.S. population.

# %% [markdown]
# ## **9.2 AI**
# For our project, we selected ChatGPT and Google AI Studio as our primary AI tools because each addressed different aspects of our work effectively. ChatGPT was chosen for its ability to interpret complex datasets, in particular NHANES respiratory health data, and to provide additional information from a wide range of sources relevant to respiratory diseases. This capability proved valuable for shaping our research direction and assisting in the drafting of our report.
#
# Google AI Studio was selected mainly for its coding and data visualisation capabilities, especially in generating accurate graphs and charts for our findings. While ChatGPT was also capable of producing code, we generally found Google AI Studio to be more consistent and precise in executing the required code without errors. This complementary use of tools allowed us to combine strong data interpretation with reliable code execution to address both our analysis and presentation needs.

# %% [markdown]
# ## **9.3 Interaction**
# When engaging with ChatGPT, we crafted targeted prompts that requested additional sources of information, potential NHANES variables, and suggestions for expanding our analysis. We reviewed the outputs critically. We fact-checked content, corrected inaccuracies, and integrated verified insights into our project. In many cases, ChatGPT’s suggestions led us to explore new data points and refine our analytical approach.
#
# For Google AI Studio, we used it primarily to debug and refine code. Our typical workflow involved first asking ChatGPT to generate code for a given chart or statistical analysis. If that code contained errors or did not perform as intended, we would then pass it to Google AI Studio, and occasionally to Google Gemini, to identify and correct the issues. This iterative back-and-forth ensured that the final code was functional, accurate, and aligned with our research objectives

# %% [markdown]
# ## **9.4 Reflection**
# Using these AI tools highlighted that, while they can accelerate research and coding tasks, they are not infallible. AI outputs can sometimes be inaccurate, incomplete, or overly general, which reinforced the need to act as a critical evaluator and fact-checker.
#
# Through this process, I learned how to formulate precise prompts, verify AI-generated information, and iterate on outputs until they met quality standards. I also gained an appreciation for AI’s ability to suggest novel approaches and uncover additional insights that might not have been immediately apparent from the data alone.
#
# However, limitations were clear. AI models may misinterpret the scope of a question, omit relevant factors, or generate code that fails under real-world conditions. These shortcomings required us to cross-reference AI outputs with authoritative sources and apply our own subject-matter knowledge. Ultimately, AI served as a valuable assistant rather than a final authority, influencing our workflow by making it more efficient but still requiring human oversight at every stage.
